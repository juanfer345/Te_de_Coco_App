# %%
# %%bash
# #Instalar liberias
# pip3 install flask
# pip3 install chatterbot
# pip3 install chatterbot==1.0.1
# Out:
# ...
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.2.19-cp36-cp36m-linux_x86_64.whl size=1151174 sha256=b3f48f282649615fcfa5d6121afe1042a1315b2162c7c870c872eb01c0b355d4
#   Stored in directory: /root/.cache/pip/wheels/2c/90/a7/3b40c6cc468abff357b38fd075429920bd0d313659d889cf8a
# Successfully built sqlalchemy
# ...
#   Found existing installation: SQLAlchemy 1.3.20
#     Uninstalling SQLAlchemy-1.3.20:
#       Successfully uninstalled SQLAlchemy-1.3.20
#   Found existing installation: python-dateutil 2.8.1
#     Uninstalling python-dateutil-2.8.1:
#       Successfully uninstalled python-dateutil-2.8.1
#   Found existing installation: ChatterBot 1.0.8
#     Uninstalling ChatterBot-1.0.8:
#       Successfully uninstalled ChatterBot-1.0.8
# ...
# ERROR: fbprophet 0.7.1 has requirement python-dateutil>=2.8.0, but you'll have python-dateutil 2.7.5 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.

# %%
# %%bash
# rm -r bot
# mkdir bot
# Out:
# rm: cannot remove 'bot': No such file or directory

# %%
# %%bash
# # en la carpeta bot crear el archivo sample.py y las carpetas templates y datos
# echo """
# from flask import Flask,render_template,request
# from chatterbot import ChatBot
# from chatterbot.trainers import ListTrainer
#
#
# app= Flask(__name__) # nombre del modulo o el paquete
# spa_bot=ChatBot('Chatterbot',storage_adapter='chatterbot.storage.SQLStorageAdapter')
# trainer= ListTrainer(spa_bot)
#
# trainer.train([
#     'Hola',
#     'Hola, bienvenido a su ChatBot preferido de su aplicación CASE ;)',
# ])
# # Tipo de diagrama
# trainer.train([
#     'Tipo de diagrama',
#     'Esquema preconcepcual (EP)',
#     'Qué tipo de diagrama recibe la app',
#     'Esquema preconcepcual (EP)',
#     'Cual es el tipo de diagrama?',
#     'Esquema preconcepcual (EP)',
#     'Cual tipo de diagrama?',
#     'Esquema preconcepcual (EP)',
#     'Entrada de la aplicación',
#     'Esquema preconcepcual (EP)',
#     'Cuál es la entrada de la aplicación?',
#     'Esquema preconcepcual (EP)',
# ])
# # Tipo de salida
# trainer.train([
#     'tipo de aplicación de salida'
#     'La aplicación de salida es una aplicación Web desarrollada en JavaScript con una BD no relacional en Mongo',
#     'resultado de la aplicación' ,
#     'La aplicación de salida es una aplicación Web desarrollada en JavaScript con una BD no relacional en Mongo',
#     'salida de la aplicacion',
#     'La aplicación de salida es una aplicación Web desarrollada en JavaScript con una BD no relacional en Mongo',
#     'Cual es la salida de la aplicación?',
#     'La aplicación de salida es una aplicación Web desarrollada en JavaScript con una BD no relacional en Mongo',
#
# ])
#
# # Entrada del tipo de documento que receibe la aplicación
# trainer.train([
#     ' formato '
#     'XML' ,
#     'En que formato' ,
#     'En formato XML' ,
#     'Cual es el formato del EP ',
#     'En formato XML',
#     'Cual es el formato del esquema preconceptual',
#     'En formato XML debe estar el EP',
#     'Cual es el formato de entrada?',
#     'En formato XML',
# ])
# # Elemento rectangulo o concepto
# trainer.train([
#     'concepto',
#     'El elemento “Rectangle ” de General en draw.io se traduce como el concepto o atributo de una entidad. ',
#     'Como represento un concepto',
#     'El elemento “Rectangle ” de General en draw.io se traduce como el concepto o atributo de una entidad. ',
#     'Que es un concepto en el EP',
#     'El elemento “Rectangle ” de General en draw.io se traduce como el concepto o atributo de una entidad. ',
#     'Como represento un concepto en el EP',
#     'El elemento “Rectangle ” de General en draw.io se traduce como el concepto o atributo de una entidad. ',
# ])
# # Uniones
# trainer.train([
#     'uniones',
#     'Las uniones entre los elementos se van a basar en la dirección desde donde se crea hasta donde va el elemento, no por el sentido de la flecha',
#     'Como funcionan las uniones',
#     'Las uniones entre los elementos se van a basar en la dirección desde donde se crea hasta donde va el elemento, no por el sentido de la flecha',
#     'Como funcionan las uniones entre los elementos',
#     'Las uniones entre los elementos se van a basar en la dirección desde donde se crea hasta donde va el elemento, no por el sentido de la flecha',
#     'Como funcionan las uniones en el EP',
#     'Las uniones entre los elementos se van a basar en la dirección desde donde se crea hasta donde va el elemento, no por el sentido de la flecha',
# ])
# # Relacion estructural
# trainer.train([
#     'relacion estructural',
#     'El elemento “Start/ End” de Data flow diagram en Draw.io se traduce como una relacion estructual',
#     'Como represento una relacion estructural',
#     'El elemento “Start/ End” de Data flow diagram en Draw.io se traduce como una relacion estructual',
#     'Como represento un tiene',
#     'El elemento “Start/ End” de Data flow diagram en Draw.io se traduce como una relacion estructual',
# ])
# # Relacion dinamica
# trainer.train([
#     'relacion dinamica',
#     'El elemento “Delibered Attribute” de Entity Relation en Draw.io se traduce como una relacion dinamica',
#     'Como represento una relacion dinamica',
#     'El elemento “Delibered Attribute” de Entity Relation en Draw.io se traduce como una relacion dinamica',
#     'Como represento una relaciónn dinámica',
#     'El elemento “Delibered Attribute” de Entity Relation en Draw.io se traduce como una relacion dinamica',
#     'Como represento una accion sobre un concepto',
#     'El elemento “Delibered Attribute” de Entity Relation en Draw.io se traduce como una relacion dinamica',
#     'Como represento una accion sobre un atributo',
#     'El elemento “Delibered Attribute” de Entity Relation en Draw.io se traduce como una relacion dinamica',
# ])
# # Usuario
# trainer.train([
#     'Como represento un usuario',
#     'El elemento “Actor” de General en draw.io se traduce como un usuario y tipo de rol. El nombre con el que se crea, aparece en la aplicación luego de subir el esquema, para acceder con ese rol a la aplicación. ',
#     'Como se representa un actor',
#     'El elemento “Actor” de General en draw.io se traduce como un usuario y tipo de rol. El nombre con el que se crea, aparece en la aplicación luego de subir el esquema, para acceder con ese rol a la aplicación. ',
#     'Como represento un actor?',
#     'El elemento “Actor” de General en draw.io se traduce como un usuario y tipo de rol. El nombre con el que se crea, aparece en la aplicación luego de subir el esquema, para acceder con ese rol a la aplicación. ',
#     'Como represento un actor en el EP',
#     'El elemento “Actor” de General en draw.io se traduce como un usuario y tipo de rol. El nombre con el que se crea, aparece en la aplicación luego de subir el esquema, para acceder con ese rol a la aplicación. ',
# ])
# # Inicialización de variables
# trainer.train([
#     'Como se incializan las variables',
#     'En el modelo preconceptual no se van a inicializar variables, solo a declarar',
#     'Como funcionan las variables en el EP',
#     'En el modelo preconceptual no se van a inicializar variables, solo a declarar',
#     'Inicialización de variables',
#     'En el modelo preconceptual no se van a inicializar variables, solo a declarar',
# ])
# # Inicialización de variables
# trainer.train([
#     'Cuales verbos pueden existir en la relación dinámica',
#     'Debe existir una relación dinámica ( “Actualizar”, “Ver”, “Borrar” o “Insertar”) por cada actor que tenga acceso a ellas, es decir, no se pueden compartir entre actores',
#     'Cuales verbos pueden existir en la relacion dinamica',
#     'Debe existir una relación dinámica ( “Actualizar”, “Ver”, “Borrar” o “Insertar”) por cada actor que tenga acceso a ellas, es decir, no se pueden compartir entre actores',
#     'Como se debe iniciar una relación dinamica',
#     'Debe existir una relación dinámica ( “Actualizar”, “Ver”, “Borrar” o “Insertar”) por cada actor que tenga acceso a ellas, es decir, no se pueden compartir entre actores',
#     'Que puede tener una relación dinámica',
#     'Debe existir una relación dinámica ( “Actualizar”, “Ver”, “Borrar” o “Insertar”) por cada actor que tenga acceso a ellas, es decir, no se pueden compartir entre actores',
# ])
#
# # Reglas de exportación
# trainer.train([
#     ' exportar ',
#     'Se debe exportar únicamente la página donde fue creado con las opciones "compresses", "selection only" y "all pages" DESHABILITADAS',
#     'Qué se debe exportar del diagrama?',
#     'Se debe exportar únicamente la página donde fue creado con las opciones "compresses", "selection only" y "all pages" DESHABILITADAS',
#     'Cómo se exporta el diagrama?',
#     'Se debe exportar únicamente la página donde fue creado con las opciones "compresses", "selection only" y "all pages" DESHABILITADAS',
#     'Cómo genero el XML?',
#     'Se debe exportar únicamente la página donde fue creado con las opciones "compresses", "selection only" y "all pages" DESHABILITADAS',
#     'Como exporto el diagrama',
#     'Se debe exportar únicamente la página donde fue creado con las opciones "compresses", "selection only" y "all pages" DESHABILITADAS',
#
# ])
#
# # Elemento no declarado
# trainer.train([
#     'Qué pasa si agrego un elemento no declarado?',
#     'En este caso aparecerá el siguiente error: Se detectó un elemento desconocido',
#     ' elemento no declarado ',
#     'En este caso aparecerá el siguiente error: Se detectó un elemento desconocido',
#     'Puedo agregar un elemento no declarado?',
#     'En este caso aparecerá el siguiente error: Se detectó un elemento desconocido',
#     'Que pasa si agrego un elemento con un estilo desconocido',
#     'En este caso aparecerá el siguiente error: Se detectó un elemento desconocido',
# ])
#
# # XML a JSON
# trainer.train([
#     'Cómo lee el XML?',
#     'Lo convierte en un .json y vincula cada entidad con sus relaciones correspondientes'
# ])
#
# # Que hace la aplicación
# trainer.train([
#     'Cómo veo la app?',
#     'Se genera una interfaz con los usuarios creados y un link para compartir (FrontEnd). Existe además otra interfaz, por cada usuario, en donde se muestra cada concepto con los atributos y relaciones dinámicas asociadas representadas en forma de botones. Esto se obtiene en forma de aplicativo web en JavaScript.',
#     'Como se ve la UI resultado',
#     'Se genera una interfaz con los usuarios creados y un link para compartir (FrontEnd). Existe además otra interfaz, por cada usuario, en donde se muestra cada concepto con los atributos y relaciones dinámicas asociadas representadas en forma de botones. Esto se obtiene en forma de aplicativo web en JavaScript.',
#     'Como se ve la interfaz resultante',
#     'Se genera una interfaz con los usuarios creados y un link para compartir (FrontEnd). Existe además otra interfaz, por cada usuario, en donde se muestra cada concepto con los atributos y relaciones dinámicas asociadas representadas en forma de botones. Esto se obtiene en forma de aplicativo web en JavaScript.',
#     'Hay más interfaces?',
#     'Existe una interfaz por cada usuario donde se muestra cada concepto con sus relaciones asociadas representadas con botones',
#     'En qué forma veo la interfaz?',
#     'Esta se ve en forma de aplicativo web en JavaScript',
#     'Qué pasa con las relaciones dinámicas no asignadas?',
#     'Estas se mostrarán de un tono más pálido, lo que significa que están deshabilitadas',
# ])
#
# # Que utiliza la aplicación
# trainer.train([
#     'Qué base de datos se usa?',
#     'Se usa una base de datos no relacional usando MongoDB',
#     'Qué tipo de base de datos se usa?',
#     'Se usa una base de datos no relacional usando MongoDB',
#     'Que BD usa',
#     'Se usa una base de datos no relacional usando MongoDB',
#     'Que uso para construir el BackEnd',
#     'Se utiliza NodeJS como servidor',
#     'Qué servidor se usa?',
#     'Se utiliza NodeJS como servidor',
#     'servidor',
#     'Se utiliza NodeJS como servidor',
# ])
#
# # Como se usa la aplicación
# trainer.train([
#     'Se guardan los datos cuando subo un nuevo esquema?',
#     'No, la base de datos es limpiada cada que se sube un nuevo esquema',
#     'Como accedo a los datos de mi esquema?',
#     'Se debe guardar el link generado en la primera interfaz',
#     'Como accedo a los datos ingresados?',
#     'Se debe guardar el link generado en la primera interfaz',
#     'Como se mantienen los datos?',
#     'Usando el link proporcionado se puede acceder de nuevo al aplicativo creado desde el esquema',
#     'persistencia',
#     'Qué hace el botón volver?',
#     'Regresa al menú de usuarios',
#     'Para que sirve Volver?',
#     'Regresa al menú de usuarios',
# ])
#
# # CRUD
# trainer.train([
#     'Que hace el botón insertar?',
#     'Al dar click en “Insertar”, se muestra una nueva página en donde es posible añadir los atributos de la entidad a la cual pertenece dicho botón. Aparecen dos botones: “Guardar Información”, “Terminar” que permiten actualizar los cambios hechos y devolverse al menú anterior, respectivamente. Es posible hacer la creación de una instancia (documento, en la base de datos no relacional) sin necesidad de haber añadido los atributos, ya que ningún campo es obligatorio.',
#     'Que pasa al dar click en insertar',
#     'Al dar click en “Insertar”, se muestra una nueva página en donde es posible añadir los atributos de la entidad a la cual pertenece dicho botón. Aparecen dos botones: “Guardar Información”, “Terminar” que permiten actualizar los cambios hechos y devolverse al menú anterior, respectivamente. Es posible hacer la creación de una instancia (documento, en la base de datos no relacional) sin necesidad de haber añadido los atributos, ya que ningún campo es obligatorio.',
#     'Que hace el botón actualizar?',
#     'Al dar click en “Actualizar”, se muestra una nueva página en donde se puede seleccionar una instancia de la entidad creada anteriormente. Se debe dar click sobre su tarjeta (cambia de color a naranja) y posteriormente dar click en el botón “Seleccionar”, el cual nos lleva a nueva página en donde todos los campos aparecen vacíos, siendo necesario modificar únicamente los atributos que se deseen, de la instancia de la entidad. Existe también el botón “Volver” para regresar al menú principal',
#     'Que pasa al dar click en actualizar?',
#     'Al dar click en “Actualizar”, se muestra una nueva página en donde se puede seleccionar una instancia de la entidad creada anteriormente. Se debe dar click sobre su tarjeta (cambia de color a naranja) y posteriormente dar click en el botón “Seleccionar”, el cual nos lleva a nueva página en donde todos los campos aparecen vacíos, siendo necesario modificar únicamente los atributos que se deseen, de la instancia de la entidad. Existe también el botón “Volver” para regresar al menú principal',
#     'Que hace el botón actualizar',
#     'Al dar click en “Actualizar”, se muestra una nueva página en donde se puede seleccionar una instancia de la entidad creada anteriormente. Se debe dar click sobre su tarjeta (cambia de color a naranja) y posteriormente dar click en el botón “Seleccionar”, el cual nos lleva a nueva página en donde todos los campos aparecen vacíos, siendo necesario modificar únicamente los atributos que se deseen, de la instancia de la entidad. Existe también el botón “Volver” para regresar al menú principal',
#     'Que pasa al dar click en borrar?',
#     'Al dar click en “Borrar”, se muestra una nueva página en donde se puede seleccionar una instancia de la entidad creada anteriormente. Se debe dar click sobre su tarjeta (cambia de color a naranja) y posteriormente dar click en el botón “Borrar”, eliminándola tanto de la base de datos como del aplicativo. Existe también el botón “Volver” para regresar al menú principal.',
#     'Que hace el botón borrar',
#     'Al dar click en “Borrar”, se muestra una nueva página en donde se puede seleccionar una instancia de la entidad creada anteriormente. Se debe dar click sobre su tarjeta (cambia de color a naranja) y posteriormente dar click en el botón “Borrar”, eliminándola tanto de la base de datos como del aplicativo. Existe también el botón “Volver” para regresar al menú principal.',
#     'Que pasa al dar click en ver?',
#     'Al dar click en “Ver”, se muestra una nueva página en donde se puede seleccionar una instancia de la entidad creada anteriormente. Se debe dar click sobre su tarjeta (cambia de color a naranja) y posteriormente dar click en el botón “Borrar”, eliminándola tanto de la base de datos como del aplicativo. Existe también el botón “Volver” para regresar al menú principal.',
#     'Que hace el botón ver',
#     'Al dar click en “Ver”, se muestra una nueva página en donde se puede seleccionar una instancia de la entidad creada anteriormente. Se debe dar click sobre su tarjeta (cambia de color a naranja) y posteriormente dar click en el botón “Borrar”, eliminándola tanto de la base de datos como del aplicativo. Existe también el botón “Volver” para regresar al menú principal.',
# ])
#
# # Requisitos no funcionales
# trainer.train([
#     'Hay algún campo obligatorio en una entidad o concepto',
#     'El aplicativo al momento de insertar cualquier entidad no requiere campos obligatorios.',
#     'Un concepto tiene un atributo obligatorio',
#     'El aplicativo al momento de insertar cualquier entidad no requiere campos obligatorios.',
#     'Como accedo a los datos ingresados?',
#     'Requisitos para ejecutar la aplicación',
#     'Para su correcto funcionamiento debe tener los programas: NodeJs, JavaScript, MongoDB, y acceso a internet.',
#     'Hay requisitos para ejecutar',
#     'Para su correcto funcionamiento debe tener los programas: NodeJs, JavaScript, MongoDB, y acceso a internet.',
#     'Cuales son los requisitos para ejecutar la aplicación',
#     'Para su correcto funcionamiento debe tener los programas: NodeJs, JavaScript, MongoDB, y acceso a internet.',
#     'En que se debe realizar el EP',
#     'El esquema preconceptual debe ser realizado en draw.io',
#     'En que programa se debe realizar el esquema preconceptual',
#     'El esquema preconceptual debe ser realizado en draw.io',
#     'Cual es el programa en el que se debe generar el EP',
#     'El esquema preconceptual debe ser realizado en draw.io',
#
# ])
#
# @app.route('/')
# def index():
#     return render_template('index.html')  #ENVIAR A HTML
#
# @app.route('/get')
# def get_bot_response():
#     userText=request.args.get('msg')  #tomar datos de la entrada, escribimos js en el index.html
#     return str(spa_bot.get_response(userText))
#
#
# if __name__=='__main__':
#     app.run()
# """ > bot/sample.py
#
# mkdir bot/templates
# touch bot/templates/index.html
# Out:
# mkdir: cannot create directory ‘bot/templates’: File exists

# %%
# Consultamos la dirección URL del servidor colab
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(5000)"))
# Out:
# https://j0sxcguxlz-496ff2e9c6d22116-5000-colab.googleusercontent.com/

# %%
# %%bash
# python3 bot/sample.py
# Out:
# Process is terminated.

# %%
# !sudo lsof -i :5000
